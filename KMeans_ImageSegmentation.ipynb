# %% [markdown]
# <a href="https://colab.research.google.com/github/mithunkumarsr/LearnComputerVisionWithMithun/blob/main/KMeans_ImageSegmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans

# %%
image = mpl.image.imread("dog.jpg")

# %%
image
# Out:
# array([[[19, 38, 48],
#         [19, 38, 48],
#         [19, 38, 48],
#         ...,
#         [15, 32, 40],
#         [16, 33, 41],
#         [20, 37, 45]],
#
#        [[22, 41, 50],
#         [22, 41, 50],
#         [22, 41, 50],
#         ...,
#         [15, 32, 40],
#         [16, 33, 41],
#         [20, 37, 45]],
#
#        [[24, 43, 53],
#         [24, 43, 53],
#         [24, 43, 53],
#         ...,
#         [15, 32, 40],
#         [16, 33, 41],
#         [20, 37, 45]],
#
#        ...,
#
#        [[ 5, 20, 28],
#         [ 3, 17, 26],
#         [ 4, 18, 27],
#         ...,
#         [26, 49, 59],
#         [26, 49, 59],
#         [26, 49, 59]],
#
#        [[ 0, 13, 21],
#         [ 0, 14, 23],
#         [ 4, 18, 27],
#         ...,
#         [26, 49, 59],
#         [26, 49, 59],
#         [26, 49, 59]],
#
#        [[ 0, 10, 19],
#         [ 0, 15, 24],
#         [ 5, 20, 28],
#         ...,
#         [30, 54, 64],
#         [30, 54, 64],
#         [30, 54, 64]]], dtype=uint8)

# %%
X = image.reshape(-1,3)

# %%
kmeans = KMeans(n_clusters=3, n_init=10)

# %%
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3, n_init=10)

# %%
segmented_img = kmeans.cluster_centers_[kmeans.labels_]
segmented_img = segmented_img.reshape(image.shape)

# %%
plt.imshow(segmented_img / 255)
